# %%
import pandas as pd

df = pd.read_csv('2023 Military Strength Ranking3.csv')
df
# Out:
#                                                   Rank Active Mil Personnel  \
# 0    145                \n             \n\t\t\t\n\t...                8,000
# 1    144                \n             \n\t\t\t\n\t...                5,000
# 2    143                \n             \n\t\t\t\n\t...                6,000
# 3    142                \n             \n\t\t\t\n\t...               17,500
# 4    141                \n             \n\t\t\t\n\t...                2,000
# ..                                                 ...                  ...
# 140  5                \n             \n\t\t\t\n\t\t...              194,000
# 141  4                \n             \n\t\t\t\n\t\t...            1,450,000
# 142  3                \n             \n\t\t\t\n\t\t...            2,000,000
# 143  2                \n             \n\t\t\t\n\t\t...              830,900
# 144  1                \n             \n\t\t\t\n\t\t...            1,390,000
#
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Active Mil Personnel', 'Reserve Mil Personnel ',
#        'Paramilitary ', 'Air Force Personnel', 'Army Personnel',
#        'Navy Personnel', 'Total Aircraft', 'Fighter Aircrafts',
#        'Attack Type Aircrafts', 'Helicopters', 'Attack Helicopteres', 'Tanks',
#        'Self-Propelled Artillerry', 'Towed Artillery', 'Rocket Artillery',
#        'Aircraft Carriers', 'Destroyers', 'Frigates', 'Corvettes',
#        'Submarines', 'Patrol Vessels', 'Mine Warfare',
#        'Purchasing Power Parity ', 'Defense Budget'],
#       dtype='object')

# %%
column_list = list(df.columns)
for column in column_list:
    df[column].info()

# %%
del df['Active Mil Personnel']
df
# Out:
#                                                   Rank Reserve Mil Personnel   \
# 0    145                \n             \n\t\t\t\n\t...                      0
# 1    144                \n             \n\t\t\t\n\t...                      0
# 2    143                \n             \n\t\t\t\n\t...                 12,000
# 3    142                \n             \n\t\t\t\n\t...                      0
# 4    141                \n             \n\t\t\t\n\t...                      0
# ..                                                 ...                    ...
# 140  5                \n             \n\t\t\t\n\t\t...                 37,000
# 141  4                \n             \n\t\t\t\n\t\t...              1,155,000
# 142  3                \n             \n\t\t\t\n\t\t...                510,000
# 143  2                \n             \n\t\t\t\n\t\t...                250,000
# 144  1                \n             \n\t\t\t\n\t\t...                442,000
#
# ...

# %%
graph_df = df['Total Aircraft']
total_aircraft_broken = graph_df.unique()
total_aircraft_broken
total_aircraft_broken[0] = total_aircraft_broken[0].split("\t\t\t\n\n\t\t\t\tReadiness: ")
total_aircraft_broken[0]
# Out:
# [' 2', '1*']

# %%
import matplotlib.pyplot as plt
